# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Read History File

# %%
df = pd.read_pickle('inference_data.pkl')

# %% [markdown]
# # Plot Metrics

# %%
plt.figure(figsize=(10,5))
plt.subplot(3,1,1)
#plt.plot(self.reward_history, 'r.-')
plt.plot(df.reset_index()['time'],df.reset_index()['Tc'])
plt.ylabel('Tc')
plt.legend(['reward'],loc='best')

plt.subplot(3,1,2)
#plt.plot(self.rms_history, 'r.-')
plt.plot(df.reset_index()['time'],df.reset_index()['T'])
plt.plot(df.reset_index()['time'],df.reset_index()['Tref'],'r--')
plt.ylabel('Temp')
plt.legend(['T', 'Tref'],loc='best')

plt.subplot(3,1,3)
plt.plot(df.reset_index()['time'],df.reset_index()['Ca'])
plt.plot(df.reset_index()['time'],df.reset_index()['Cref'],'r--')
plt.legend(['Ca', 'Cref'],loc='best')
plt.ylabel('Concentration')
plt.xlabel('iteration')
# Out:
# Text(0.5, 0, 'iteration')

# %% [markdown]
# # Actions

# %%
df['Tc'].diff().reset_index(drop=True).plot()
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,10))
plt.subplot(4,1,1)
plt.plot(df.reset_index()['reward'].rolling(window=90).mean(), 'b')
plt.plot(df.reset_index()['reward'].rolling(window=400).mean(), 'r')
plt.ylabel('Reward Moving Average')

plt.subplot(4,1,2)

plt.plot(df.reset_index()['time'])
plt.ylabel('Episode Length')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/composabl/lib/python3.8/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~/anaconda3/envs/composabl/lib/python3.8/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/envs/composabl/lib/python3.8/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'reward'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[39], line 3
#       1 plt.figure(figsize=(15,10))
#       2 plt.subplot(4,1,1)
# ----> 3 plt.plot(df.reset_index()['reward'].rolling(window=90).mean(), 'b')
#       4 plt.plot(df.reset_index()['reward'].rolling(window=400).mean(), 'r')
#       5 plt.ylabel('Reward Moving Average')
#
# File ~/anaconda3/envs/composabl/lib/python3.8/site-packages/pandas/core/frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~/anaconda3/envs/composabl/lib/python3.8/site-packages/pandas/core/indexes/base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'reward'
