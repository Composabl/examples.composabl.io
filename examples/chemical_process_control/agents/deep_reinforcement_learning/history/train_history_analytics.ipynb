# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Read History File

# %%
df = pd.read_pickle(f"./db.pkl")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_pickle(f"./history/db.pkl")
#
# File ~/anaconda3/envs/composabl_test/lib/python3.8/site-packages/pandas/io/pickle.py:179, in read_pickle(filepath_or_buffer, compression, storage_options)
#     115 """
#     116 Load pickled pandas object (or any object) from file.
#     117
#    (...)
#     176 4    4    9
#     177 """
#     178 excs_to_catch = (AttributeError, ImportError, ModuleNotFoundError, TypeError)
# --> 179 with get_handle(
#     180     filepath_or_buffer,
#     181     "rb",
#     182     compression=compression,
#     183     is_text=False,
#     184     storage_options=storage_options,
#     185 ) as handles:
#     186     # 1) try standard library Pickle
#     187     # 2) try pickle_compat (older pandas version) to handle subclass changes
#     188     # 3) try pickle_compat with latin-1 encoding upon a UnicodeDecodeError
#     190     try:
#     191         # TypeError for Cython complaints about object.__new__ vs Tick.__new__
#     192         try:
#
# File ~/anaconda3/envs/composabl_test/lib/python3.8/site-packages/pandas/io/common.py:868, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#    (...)
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
# --> 868         handle = open(handle, ioargs.mode)
#     869     handles.append(handle)
#     871 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: './history/db.pkl'

# %% [markdown]
# # Plot Metrics

# %%
plt.figure(figsize=(10,5))
plt.subplot(3,1,1)
plt.scatter(df.reset_index()['time'],df.reset_index()['reward'],s=0.5, alpha=0.2)
plt.ylabel('Reward')
plt.legend(['reward'],loc='best')

plt.subplot(3,1,2)
plt.scatter(df.reset_index()['time'],df.reset_index()['rms'],s=0.5, alpha=0.1)
plt.ylabel('RMS error')
plt.legend(['RMS'],loc='best')

plt.subplot(3,1,3)
plt.scatter(df.reset_index()['time'],df.reset_index()['Ca'],s=0.6, alpha=0.1)
plt.scatter(df.reset_index()['time'],df.reset_index()['Cref'],s=0.6, alpha=0.9)
plt.ylabel('Ca')
plt.legend(['Ca'],loc='best')
plt.xlabel('iteration')
# Out:
# Text(0.5, 0, 'iteration')

# %%
plt.figure(figsize=(15,10))
plt.subplot(4,1,1)
plt.plot(df.reset_index()['reward'].rolling(window=90).mean(), 'b')
plt.plot(df.reset_index()['reward'].rolling(window=400).mean(), 'r')
plt.ylabel('Reward Moving Average')

plt.subplot(4,1,2)

plt.plot(df.reset_index()['time'])
plt.ylabel('Episode Length')
# Out:
# Text(0, 0.5, 'Episode Length')
